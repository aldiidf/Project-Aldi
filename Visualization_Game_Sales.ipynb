# %% [markdown]
# <a href="https://colab.research.google.com/github/aldiidf/Project-Aldi/blob/main/Visualization_Game_Sales.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np #numerical operation
import matplotlib.pyplot as plt #untuk visualization
from google.colab import files
import seaborn as sns

# %% [markdown]
# # Tampil Data Upload CSV

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-945c8257-473e-431e-b7d6-cfd4213bf60d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-945c8257-473e-431e-b7d6-cfd4213bf60d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
game_data = pd.read_csv("GameSales.csv" , error_bad_lines=False, na_values = ["??", "????"])
print(game_data)
# Out:
#     Name;Sales;Series;Release;Genre;Developer;Publisher
# 0    7 Days to Die;2;7 Days;6/1/2016;Survival horro...
# 1    Age of Empires;3;Age of Empires;10/1/1997;Real...
# 2    Age of Empires II: The Age of Kings;2;Age of E...
# 3    Age of Mythology;1;Age of Empires;10/1/2002;Re...
# 4    Age of Empires III;2;Age of Empires;10/1/2005;...
# ..                                                 ...
# 127  Rust;9;;2/1/2018;Survival;Facepunch Studios;Fa...
# 128  The Forest;5;;4/1/2018;Survival;Endnight Games...
# 129   Mordhau;1;;4/1/2019;Action;Triternion;Triternion
# 130  Fall Guys;10;;8/1/2020;Battle royale;Mediatoni...
# 131  Valheim;6;;2/1/2021;Survival;Iron Gate;Coffee ...
#
# [132 rows x 1 columns]
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %% [markdown]
# ## Clean Data

# %%
game_data.dropna(axis = 0, inplace = True)

# %%
print(game_data)
# Out:
#     Name;Sales;Series;Release;Genre;Developer;Publisher
# 0    7 Days to Die;2;7 Days;6/1/2016;Survival horro...
# 1    Age of Empires;3;Age of Empires;10/1/1997;Real...
# 2    Age of Empires II: The Age of Kings;2;Age of E...
# 3    Age of Mythology;1;Age of Empires;10/1/2002;Re...
# 4    Age of Empires III;2;Age of Empires;10/1/2005;...
# ..                                                 ...
# 127  Rust;9;;2/1/2018;Survival;Facepunch Studios;Fa...
# 128  The Forest;5;;4/1/2018;Survival;Endnight Games...
# 129   Mordhau;1;;4/1/2019;Action;Triternion;Triternion
# 130  Fall Guys;10;;8/1/2020;Battle royale;Mediatoni...
# 131  Valheim;6;;2/1/2021;Survival;Iron Gate;Coffee ...
#
# [132 rows x 1 columns]

# %% [markdown]
# # Tampil Data Menggunakan SpreadSheet

# %%
sheet_url = 'https://docs.google.com/spreadsheets/d/10poofg-l8DMdtUgGy8mOpra2IHmA9EQC7drmF9AyYHA/edit#gid=1485085913'
sheet_url_trf = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')
print(sheet_url_trf)
df = pd.read_csv(sheet_url_trf)
df
# Out:
# https://docs.google.com/spreadsheets/d/10poofg-l8DMdtUgGy8mOpra2IHmA9EQC7drmF9AyYHA/export?format=csv&gid=1485085913
#                                      Name  Sales          Series    Release  \
# 0           PlayerUnknown's Battlegrounds   42.0             NaN  12/1/2017
# 1                               Minecraft   33.0       Minecraft  11/1/2011
# 2                              Diablo III   20.0          Diablo   5/1/2012
# 3                             Garry's Mod   20.0             NaN  11/1/2006
# 4                                Terraria   17.2             NaN   5/1/2011
# ..                                    ...    ...             ...        ...
# 172        Who Wants to Be a Millionaire?    1.0             NaN  11/1/1999
# 173  Wing Commander 3: Heart of the Tiger    1.0  Wing Commander  12/1/1994
# 174                            Zoo Tycoon    1.0      Zoo Tycoon  10/1/2001
# 175      StarCraft II: Heart of the Swarm    1.0       StarCraft   3/1/2013
# ...

# %% [markdown]
# ## Clean Data

# %%
df_cleanned = df.copy()
df_cleanned['Release'] = pd.to_datetime(df_cleanned['Release'])
df_cleanned.head()
# Out:
#                             Name  Sales     Series    Release  \
# 0  PlayerUnknown's Battlegrounds   42.0        NaN 2017-12-01
# 1                      Minecraft   33.0  Minecraft 2011-11-01
# 2                     Diablo III   20.0     Diablo 2012-05-01
# 3                    Garry's Mod   20.0        NaN 2006-11-01
# 4                       Terraria   17.2        NaN 2011-05-01
#
#                  Genre               Developer               Publisher
# 0        Battle royale            PUBG Studios                 Krafton
# 1    Sandbox, survival          Mojang Studios          Mojang Studios
# 2  Action role-playing  Blizzard Entertainment  Blizzard Entertainment
# 3              Sandbox       Facepunch Studios                   Valve
# 4     Action-adventure                Re-Logic                Re-Logic

# %%
df_cleanned.dropna(axis = 0, inplace = True)

# %%
df_cleanned
# Out:
#                                      Name  Sales          Series    Release  \
# 1                               Minecraft   33.0       Minecraft 2011-11-01
# 2                              Diablo III   20.0          Diablo 2012-05-01
# 5                       World of Warcraft   14.0        Warcraft 2004-11-01
# 6                             Half-Life 2   12.0       Half-Life 2004-11-01
# 7                The Witcher 3: Wild Hunt   12.0     The Witcher 2015-05-01
# ..                                    ...    ...             ...        ...
# 171    Warhammer Online: Age of Reckoning    1.0       Warhammer 2008-09-01
# 173  Wing Commander 3: Heart of the Tiger    1.0  Wing Commander 1994-12-01
# 174                            Zoo Tycoon    1.0      Zoo Tycoon 2001-10-01
# 175      StarCraft II: Heart of the Swarm    1.0       StarCraft 2013-03-01
# 176      StarCraft II: Legacy of the Void    1.0       StarCraft 2015-11-01
#
# ...

# %%
df_cleanned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 141 entries, 1 to 176
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       141 non-null    object
#  1   Sales      141 non-null    float64
#  2   Series     141 non-null    object
#  3   Release    141 non-null    datetime64[ns]
#  4   Genre      141 non-null    object
#  5   Developer  141 non-null    object
#  6   Publisher  141 non-null    object
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 8.8+ KB

# %%
df_cleanned.columns
# Out:
# Index(['Name', 'Sales', 'Series', 'Release', 'Genre', 'Developer',
#        'Publisher'],
#       dtype='object')

# %%
#looping cek typo
for col_name in ['Name', 'Sales', 'Series', 'Release', 'Genre', 'Developer','Publisher']:
       print(df_cleanned[col_name].value_counts(), '\n')
# Out:
# StarCraft II: Heart of the Swarm    2
# StarCraft II: Legacy of the Void    2
# Minecraft                           1
# Command & Conquer: Tiberian Sun     1
# Crusader Kings II                   1
#                                    ..
# Myst                                1
# Lords of the Realm II               1
# Caesar III                          1
# Caesar II                           1
# Zoo Tycoon                          1
# Name: Name, Length: 139, dtype: int64
#
# 1.0     62
# 2.0     28
# 3.0      9
# 4.0      6
# 2.5      4
# 1.5      3
# 6.0      3
# 11.0     2
# 1.2      2
# 1.3      2
# 5.5      2
# 5.0      2
# 12.0     2
# 1.1      1
# 1.8      1
# 14.0     1
# 2.1      1
# 3.3      1
# 2.7      1
# 10.0     1
# 3.6      1
# 20.0     1
# 6.5      1
# 7.0      1
# 8.0      1
# 9.0      1
# 33.0     1
# Name: Sales, dtype: int64
#
# StarCraft                6
# Command & Conquer        5
# Civilization             4
# Age of Empires           4
# ...

# %%
df_cleanned.head()
# Out:
#                        Name  Sales       Series    Release  \
# 1                 Minecraft   33.0    Minecraft 2011-11-01
# 2                Diablo III   20.0       Diablo 2012-05-01
# 5         World of Warcraft   14.0     Warcraft 2004-11-01
# 6               Half-Life 2   12.0    Half-Life 2004-11-01
# 7  The Witcher 3: Wild Hunt   12.0  The Witcher 2015-05-01
#
#                   Genre               Developer               Publisher
# 1     Sandbox, survival          Mojang Studios          Mojang Studios
# 2   Action role-playing  Blizzard Entertainment  Blizzard Entertainment
# 5                MMORPG  Blizzard Entertainment  Blizzard Entertainment
# 6  First-person shooter                   Valve         Valve (digital)
# 7   Action role-playing          CD Projekt Red              CD Projekt

# %%
agg_daily = df_cleanned.groupby('Release', as_index=False)['Name', 'Genre', 'Sales'].sum() #groupby = pivot di excel
agg_daily.head()
# Out:
# <ipython-input-46-cf40d4bfa6a1>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   agg_daily = df_cleanned.groupby('Release', as_index=False)['Name', 'Genre', 'Sales'].sum() #groupby = pivot di excel
#      Release  Sales
# 0 1984-12-01    1.0
# 1 1985-06-01    4.0
# 2 1985-11-01    1.5
# 3 1988-01-01    1.0
# 4 1988-08-01    5.5

# %%
df_cleanned['Genre'].duplicated().sum()
# Out:
# 2

# %%
df.to_csv("GameSalesNew.csv")

# %%
plt.rcParams['figure.figsize'] = (20,5)
sns.barplot('Series', 'Sales', data=df.sort_values('Sales', ascending=False))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lineplot(data=agg_daily, x= 'Release', y = 'Sales')
